# %%
df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv(
        "/Volumes/retail_catalog/sales_demo/sales_vol/"
    )

display(df)

df.write.mode("overwrite").saveAsTable(
    "retail_catalog.sales_demo.raw_sales"
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>product</th><th>region</th><th>sales_amount</th><th>quantity</th><th>sale_date</th></tr></thead><tbody><tr><td>1</td><td>Laptop</td><td>North</td><td>50000</td><td>2</td><td>2026-05-10</td></tr><tr><td>2</td><td>Mouse</td><td>West</td><td>2000</td><td>5</td><td>2026-05-10</td></tr><tr><td>3</td><td>Keyboard</td><td>South</td><td>3000</td><td>3</td><td>2026-05-10</td></tr><tr><td>4</td><td>Monitor</td><td>North</td><td>15000</td><td>1</td><td>2026-05-10</td></tr></tbody></table></div>
